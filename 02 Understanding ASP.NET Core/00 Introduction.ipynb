# %% [markdown]
# ***Microsoft*** created `ASP.NET Core` to be an additional layer on top of `console applications`

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
