# %% [markdown]
# `EF Core` is a library that provides an `object-oriented way` to ***access databases***.

# %% [markdown]
# It acts as an `object-relational mapper (ORM)`, communicating with the
# database for you and ***mapping database responses*** to `.NET classes`

# %% [markdown]
# ![image.png](attachment:image.png)
